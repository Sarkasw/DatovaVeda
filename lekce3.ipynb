# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

# %%
data = pd.read_csv("diabetes.csv")
labels = {0: "no", 1: "yes"}
data["Outcome"] = data["Outcome"].map(labels)
sns.boxplot(data, x="Outcome", y="BloodPressure")
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %%
sns.boxplot(data, x="Outcome", y="BloodPressure", whis=[5, 95])
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %%
data = data[data["BloodPressure"] > 0]
sns.boxplot(data, x="Outcome", y="BloodPressure", whis=[5, 95])
# Out:
# <Axes: xlabel='Outcome', ylabel='BloodPressure'>

# %%
data_yes = data[data["Outcome"] == "yes"]
np.quantile(data_yes["BloodPressure"], 0.25)
# Out:
# 68.0

# %%
np.quantile(data_yes["BloodPressure"], 0.75)
# Out:
# 84.0

# %%
sns.histplot(data=data, x="BloodPressure")
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %%
sns.histplot(data=data, x="BloodPressure", bins=range(0, 130, 3))
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %%
sns.displot(data=data, x="BloodPressure", kde=True)

# %%
data = pd.read_csv("WA_Marketing-Campaign.csv")

# %%
data = data.reset_index()
data["Promotion"].value_counts()
# Out:
# Promotion
# 2    188
# 1    172
# Name: count, dtype: int64

# %%
data_promotion_1 = data[data["Promotion"] == 1]
data_promotion_2 = data[data["Promotion"] == 2]

# %%
stats.normaltest(data_promotion_1["SalesInThousands"])
# Out:
# NormaltestResult(statistic=17.938630886905376, pvalue=0.00012725527577741506)

# %%
data = data[data["MarketSize"] == "Medium"]

# %%
data
# Out:
#      index  MarketID MarketSize  LocationID  AgeOfStore  Promotion  week  \
# 0        0         1     Medium           2           5          2     1
# 1        1         1     Medium           2           5          2     2
# 2        2         1     Medium           2           5          2     3
# 3        3         1     Medium           2           5          2     4
# 4        4         1     Medium           3          12          1     1
# ..     ...       ...        ...         ...         ...        ...   ...
# 287    287         9     Medium         807           1          2     4
# 288    288         9     Medium         810          13          1     1
# 289    289         9     Medium         810          13          1     2
# 290    290         9     Medium         810          13          1     3
# 291    291         9     Medium         810          13          1     4
#
#      SalesInThousands
# 0               27.81
# 1               34.67
# 2               27.98
# 3               27.72
# 4               44.54
# ..                ...
# 287             55.91
# 288             49.30
# 289             61.80
# 290             58.00
# 291             55.20
#
# [204 rows x 8 columns]

# %%
data.reset_index()
# Out:
#      level_0  index  MarketID MarketSize  LocationID  AgeOfStore  Promotion  \
# 0          0      0         1     Medium           2           5          2
# 1          1      1         1     Medium           2           5          2
# 2          2      2         1     Medium           2           5          2
# 3          3      3         1     Medium           2           5          2
# 4          4      4         1     Medium           3          12          1
# ..       ...    ...       ...        ...         ...         ...        ...
# 199      287    287         9     Medium         807           1          2
# 200      288    288         9     Medium         810          13          1
# 201      289    289         9     Medium         810          13          1
# 202      290    290         9     Medium         810          13          1
# 203      291    291         9     Medium         810          13          1
#
#      week  SalesInThousands
# 0       1             27.81
# 1       2             34.67
# 2       3             27.98
# 3       4             27.72
# 4       1             44.54
# ..    ...               ...
# 199     4             55.91
# 200     1             49.30
# 201     2             61.80
# 202     3             58.00
# 203     4             55.20
#
# [204 rows x 9 columns]

# %%
data_promotion_1 = data[data["Promotion"] == 1]
data_promotion_2 = data[data["Promotion"] == 2]

# %%
stats.normaltest(data_promotion_1["SalesInThousands"])
# Out:
# NormaltestResult(statistic=7.671792543063383, pvalue=0.021581986479073396)

# %%
stats.normaltest(data_promotion_2["SalesInThousands"])
# Out:
# NormaltestResult(statistic=2.804048717620895, pvalue=0.2460982681449423)

# %%
data = pd.read_csv("global_hotel_reviews.csv")

# %%
data.head()
# Out:
#    Rating        Date                                        Description  \
# 0      10  18-09-2023  Très bon hôtel comme attendu. On s’occupe de v...
# 1      10  05-09-2023  Magnifique hôtel \nTrès belles prestations \nP...
# 2       8  31-10-2022  personnel à l'écoute et agréable, mais les cha...
# 3      10  03-09-2022  Accueil chaleureux, bon service et bonne nourr...
# 4      10  07-12-2021  Excellent Hotel bien situé, excellent service ...
#
#              Hotel_name    City Country
# 0  barriere-le-majestic  Cannes  France
# 1  barriere-le-majestic  Cannes  France
# 2  barriere-le-majestic  Cannes  France
# 3  barriere-le-majestic  Cannes  France
# 4  barriere-le-majestic  Cannes  France

# %%
data_fr = data[data["Country"] == "France"]
data_sw = data[data["Country"] == "Switzerland"]

# %%
data_fr["Rating"].mean()
# Out:
# 8.845215157353886

# %%
data_sw["Rating"].mean()
# Out:
# 8.441754916792739

# %%
sns.countplot(data=data, x="Rating", hue="Country")
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %%
stats.mannwhitneyu(data_fr["Rating"],data_sw["Rating"])
# Out:
# MannwhitneyuResult(statistic=595459.0, pvalue=2.7190215861872277e-11)

# %%
data = pd.read_csv("salaries-2022.csv")
data.head()
# Out:
#           Surname Given name       Position title Salary paid ($)  \
# 0    ABDEL-RAHMAN      EIHAB            Professor      210,256.84
# 1  ABOUEE MEHRIZI    HOSSEIN  Associate Professor      206,893.56
# 2       ABUKHDEIR  NASSER M.  Associate Professor      176,116.32
# 3         ACHESON  KATHERINE            Professor      193,308.12
# 4           ACKER     STACEY  Associate Professor      135,384.80
#
#   Taxable benefits ($)
# 0               301.76
# 1               630.20
# 2               591.56
# 3               708.72
# 4               469.72

# %%
data["Salary paid ($)"] = data["Salary paid ($)"].str.replace(",","").astype(float)
data.head()
# Out:
#           Surname Given name       Position title  Salary paid ($)  \
# 0    ABDEL-RAHMAN      EIHAB            Professor        210256.84
# 1  ABOUEE MEHRIZI    HOSSEIN  Associate Professor        206893.56
# 2       ABUKHDEIR  NASSER M.  Associate Professor        176116.32
# 3         ACHESON  KATHERINE            Professor        193308.12
# 4           ACKER     STACEY  Associate Professor        135384.80
#
#   Taxable benefits ($)
# 0               301.76
# 1               630.20
# 2               591.56
# 3               708.72
# 4               469.72

# %%
sns.histplot(data=data, x="Salary paid ($)", hue="Position title")
# Out:
# <Axes: xlabel='Salary paid ($)', ylabel='Count'>

# %%
data_prof = data[data["Position title"] == "Professor"]
data_asoc_prof = data[data["Position title"] == "Associate Professor"]

# %%
stats.normaltest(data_prof["Salary paid ($)"])
# Out:
# NormaltestResult(statistic=37.066560324413814, pvalue=8.935085116360102e-09)

# %%
stats.mannwhitneyu(data_prof["Salary paid ($)"], data_asoc_prof["Salary paid ($)"], alternative="greater")
# Out:
# MannwhitneyuResult(statistic=162896.0, pvalue=3.1384171623279043e-65)

# %%
data = pd.read_csv("insurance.csv")
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
np.quantile(data["charges"], 0.25)
# Out:
# 4740.28715

# %%
sns.boxplot(data=data, x="smoker", y="charges")
# Out:
# <Axes: xlabel='smoker', ylabel='charges'>

# %%
sns.histplot(data, x="charges", kde=True)
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
from scipy import stats
stats.normaltest(data["bmi"])
# Out:
# NormaltestResult(statistic=17.581447872784118, pvalue=0.0001521377897266011)

# %%
stats.shapiro(data["bmi"])
# Out:
# ShapiroResult(statistic=0.9938864621676107, pvalue=2.6046836879834408e-05)

# %%
data["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
np.quantile(a=[12, 13, 14],q=[0,50])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 np.quantile(a=[12, 13, 14],q=[0,50])
#
# File c:\Users\sarka\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:4542, in quantile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4540 q = np.asanyarray(q)
#    4541 if not _quantile_is_valid(q):
# -> 4542     raise ValueError("Quantiles must be in the range [0, 1]")
#    4543 return _quantile_unchecked(
#    4544     a, q, axis, out, overwrite_input, method, keepdims)
#
# ValueError: Quantiles must be in the range [0, 1]

# %%
np.quantile([3, 4, 7, 8, 10, 12, 15, 19], 0.30)
# Out:
# 7.1
